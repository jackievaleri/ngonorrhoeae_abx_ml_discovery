# %%
import pandas as pd
from utils import process_preds, evaluate_scores, evaluate_similarities
# Out:
# /Users/jackie16201/Desktop/Spring_2023/ngonorrhoeae_abx_ml_discovery/src/utils.py:5: DeprecationWarning: The rdkit.Chem.MCS module is deprecated; please use rdkit.Chem.rdFMCS instead.
#   from rdkit.Chem import MCS

# %% [markdown]
# # PK+37K model on 800k dataset

# %%
# read in data
data_dir = '../out/predictions_from_models/pk_37k_model/800k/'
df = pd.read_csv(data_dir + 'broad800K_melis_predictions_04_25_2022.csv')
print('total number of predictions: ', len(df))
meta = pd.read_csv('../data/library_info/PublicStructures.txt', sep = '\t')
df = df.merge(meta, left_on = 'smiles', right_on = 'SMILES', how = 'left')
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df.to_csv(data_dir + 'clean_preds_05_02_2022.csv', index = False)
df
# Out:
# total number of predictions:  799147
#                                                    smiles       hit  \
# 0                       Cc1ccn(n1)CN1CCN(Cn2ccc(n2)C)C1=S  0.015454
# 1        C1OC(OC[C@H]2O[C@@H](O[C@@H]12)c1ccccc1)c1ccccc1  0.013225
# 2                   CN(C)CCOC(=O)c1ccc2[nH]c3c(c2c1)CSCC3  0.008279
# 3                          CCN(CC)CCOc1ccc2nc(sc2c1)N(C)C  0.072864
# 4                       CC1=CC(=O)O[C@@H]1Cc1ccc2ccccc2n1  0.011440
# ...                                                   ...       ...
# 799142  Cc1cc(n(n1)[C@H]1CCS(=O)(=O)C1)NS(=O)(=O)c1c(n...  0.020572
# 799143  Fc1ccc(cc1)S(=O)(=O)CCCC(=O)Nc1nc-2c(s1)CSc1cc...  0.078468
# 799144                COc1cccc(c1)/C=C/1\Oc2cc(ccc2C1=O)O  0.119072
# 799145  CCc1ccc(cc1)S(=O)(=O)c1nnn2c3ccc(cc3c(nc12)N1C...  0.077788
# 799146                Oc1ccc(cc1)C(=O)/C=C/c1ccc(cc1Cl)Cl  0.281735
#
#         hit_epi_unc           Name  PROJECT_CODE      PROJECT_NAME  \
# 0          0.000655  BRD-K08172813          2001  General HTS Sets
# 1          0.000410  BRD-A88988282          2001  General HTS Sets
# 2          0.000119  BRD-K29501884          2001  General HTS Sets
# 3          0.008563  BRD-K03978601          2001  General HTS Sets
# 4          0.000161  BRD-A38938490          2001  General HTS Sets
# ...             ...            ...           ...               ...
# 799142     0.000773  BRD-K00023370          5001              CMAP
# 799143     0.006089  BRD-K00022740          5001              CMAP
# 799144     0.011544  BRD-K00022774          5001              CMAP
# 799145     0.002676  BRD-K00022896          5001              CMAP
# 799146     0.045236  BRD-K00022758          5001              CMAP
#
#                                                  CXSMILES STEREO_COMMENTS  \
# 0                       Cc1ccn(CN2CCN(Cn3ccc(C)n3)C2=S)n1        as drawn
# 1       C1OC(OC[C@@H]2O[C@H](O[C@H]12)c1ccccc1)c1ccccc...        as drawn
# 2                     CN(C)CCOC(=O)c1ccc2[nH]c3CCSCc3c2c1        as drawn
# 3                          CCN(CC)CCOc1ccc2nc(sc2c1)N(C)C        as drawn
# 4          CC1=CC(=O)O[C@@H]1Cc1ccc2ccccc2n1 |&1:6,r,t:1|        as drawn
# ...                                                   ...             ...
# 799142  Cc1cc(NS(=O)(=O)c2c(C)noc2C)n(n1)[C@H]1CCS(=O)...        as drawn
# 799143  Fc1ccc(cc1)S(=O)(=O)CCCC(=O)Nc1nc-2c(CSc3ccccc...        as drawn
# 799144                 COc1cccc(\C=C2/Oc3cc(O)ccc3C2=O)c1        as drawn
# 799145  CCc1ccc(cc1)S(=O)(=O)c1nnn2c1nc(N1CCC[C@@H](C)...        as drawn
# 799146                Oc1ccc(cc1)C(=O)\C=C\c1ccc(Cl)cc1Cl        as drawn
#
#                                                    SMILES
# 0                       Cc1ccn(n1)CN1CCN(Cn2ccc(n2)C)C1=S
# 1        C1OC(OC[C@H]2O[C@@H](O[C@@H]12)c1ccccc1)c1ccccc1
# 2                   CN(C)CCOC(=O)c1ccc2[nH]c3c(c2c1)CSCC3
# 3                          CCN(CC)CCOc1ccc2nc(sc2c1)N(C)C
# 4                       CC1=CC(=O)O[C@@H]1Cc1ccc2ccccc2n1
# ...                                                   ...
# 799142  Cc1cc(n(n1)[C@H]1CCS(=O)(=O)C1)NS(=O)(=O)c1c(n...
# 799143  Fc1ccc(cc1)S(=O)(=O)CCCC(=O)Nc1nc-2c(s1)CSc1cc...
# 799144                COc1cccc(c1)/C=C/1\Oc2cc(ccc2C1=O)O
# 799145  CCc1ccc(cc1)S(=O)(=O)c1nnn2c3ccc(cc3c(nc12)N1C...
# 799146                Oc1ccc(cc1)C(=O)/C=C/c1ccc(cc1Cl)Cl
#
# [799147 rows x 9 columns]

# %%
#process_preds(df, smiles_col = 'smiles', hit_col = 'hit', path = data_dir)
df = evaluate_scores(df, hit_col = 'hit')
df = df[df['hit'] > 0.4] # looks like a good score cut-off to start with
df = evaluate_similarities(df, smiles_col = 'smiles', path = data_dir, train_set_path = '../data/data_prep_for_ml/data_prep_for_ml_pk_37k_screen/FULL_03_19_2022.csv')
df.to_csv(data_dir + 'inh04_preds_with_tanimoto_analysis.csv', index = False)
# Out:
# Total number in df:  799147
# >0.1: 110790
# >0.2: 49465
# >0.30000000000000004: 27694
# >0.4: 16899
# >0.5: 10600
# >0.6: 6771
# >0.7000000000000001: 4216
# >0.8: 2361
# >0.9: 1055
# Computing tanimoto scores against abx...
# [18:40:58] WARNING: not removing hydrogen atom without neighbors
# Computing tanimoto scores against training set...
# [18:42:03] Unusual charge on atom 0 number of radical electrons set to zero

# %%
# need to fill in the rest with 15_revamped_clustering_evaluate_model_preds_from_Broad800K_05_02_2022
